# %% [markdown]
# ## Execute session
# Provide `experiment_name`, `patient_id`, `medication_state`, `session_id`, and `calibration_id` to identify a session that was previously initialized.

# %%
from session.Execution import Execution

experiment_name = "adbs_stimdur"
patient_id = "XXX"
medication_state = "Off" # "Off" or "On"
session_id = 1
calibration_id = 1

session_execution = Execution(experiment_name, patient_id, medication_state, session_id, calibration_id)

# %% [markdown]
# Choose a condition as `condition_name`. Running the cell will start timeflux. Start labrecorder and start recording. Choose a stimulation state as `stimulation` (only dbsoff has stimulation state StimOff).

# %%
condition_name = "dbson" # "dbson", "dbsoff", "termination200", "termination1000", "termination10000"
stimulation = "StimOn" # "StimOff", "StimOn"
session_execution.start_stimulation(condition_name, stimulation)
